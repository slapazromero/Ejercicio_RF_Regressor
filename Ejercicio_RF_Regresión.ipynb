# %% [markdown]
# <a href="https://colab.research.google.com/github/slapazromero/Ejercicio_RF_Regressor/blob/main/Ejercicio_RF_Regresi%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importación de librerías necesarias.

# %%
import pydot
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from IPython.display import Image
from io import StringIO
from joblib import dump
from datetime import time

# %% [markdown]
# # Preproceso.

# %% [markdown]
# ## Importacion de los datos del dataset.

# %%
bike = pd.read_csv('hour.csv')

# %% [markdown]
# ## Mostrar las primeras y ultimas filas del dataframe importado.

# %%
bike.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
bike.tail()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49

# %% [markdown]
# ## Modificaciones de los datos.

# %%
bike = bike.drop('instant', axis=1)
bike = bike.drop('casual', axis=1)
bike = bike.drop('registered', axis=1)

# %%
bike['date_time'] = bike.apply(lambda x: pd.datetime.combine(pd.to_datetime(x['dteday']).date(), time(x['hr'])), axis=1)
# Out:
# <ipython-input-7-1a53dd690983>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   bike['date_time'] = bike.apply(lambda x: pd.datetime.combine(pd.to_datetime(x['dteday']).date(), time(x['hr'])), axis=1)

# %%
bike = bike.drop('dteday', axis=1)
bike = bike.drop('hr', axis=1)

# %%
bike.set_index('date_time', inplace=True)

# %% [markdown]
# ## Mostrar las primeras y ultimas filas del dataframe modificado.

# %%
bike.head()
# Out:
#                      season  yr  mnth  holiday  weekday  workingday  \
# date_time
# 2011-01-01 00:00:00       1   0     1        0        6           0
# 2011-01-01 01:00:00       1   0     1        0        6           0
# 2011-01-01 02:00:00       1   0     1        0        6           0
# 2011-01-01 03:00:00       1   0     1        0        6           0
# 2011-01-01 04:00:00       1   0     1        0        6           0
#
#                      weathersit  temp   atemp   hum  windspeed  cnt
# date_time
# 2011-01-01 00:00:00           1  0.24  0.2879  0.81        0.0   16
# 2011-01-01 01:00:00           1  0.22  0.2727  0.80        0.0   40
# 2011-01-01 02:00:00           1  0.22  0.2727  0.80        0.0   32
# 2011-01-01 03:00:00           1  0.24  0.2879  0.75        0.0   13
# 2011-01-01 04:00:00           1  0.24  0.2879  0.75        0.0    1

# %%
bike.tail()
# Out:
#                      season  yr  mnth  holiday  weekday  workingday  \
# date_time
# 2012-12-31 19:00:00       1   1    12        0        1           1
# 2012-12-31 20:00:00       1   1    12        0        1           1
# 2012-12-31 21:00:00       1   1    12        0        1           1
# 2012-12-31 22:00:00       1   1    12        0        1           1
# 2012-12-31 23:00:00       1   1    12        0        1           1
#
#                      weathersit  temp   atemp   hum  windspeed  cnt
# date_time
# 2012-12-31 19:00:00           2  0.26  0.2576  0.60     0.1642  119
# 2012-12-31 20:00:00           2  0.26  0.2576  0.60     0.1642   89
# 2012-12-31 21:00:00           1  0.26  0.2576  0.60     0.1642   90
# 2012-12-31 22:00:00           1  0.26  0.2727  0.56     0.1343   61
# 2012-12-31 23:00:00           1  0.26  0.2727  0.65     0.1343   49

# %% [markdown]
# ## Mostrar parámetros estadísticos de los datos (media, desviación típica, cuartiles, etc.)

# %%
bike.describe()
# Out:
#              season            yr          mnth       holiday       weekday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       2.501640      0.502561      6.537775      0.028770      3.003683
# std        1.106918      0.500008      3.438776      0.167165      2.005771
# min        1.000000      0.000000      1.000000      0.000000      0.000000
# 25%        2.000000      0.000000      4.000000      0.000000      1.000000
# 50%        3.000000      1.000000      7.000000      0.000000      3.000000
# 75%        3.000000      1.000000     10.000000      0.000000      5.000000
# max        4.000000      1.000000     12.000000      1.000000      6.000000
#
#          workingday    weathersit          temp         atemp           hum  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.682721      1.425283      0.496987      0.475775      0.627229
# std        0.465431      0.639357      0.192556      0.171850      0.192930
# min        0.000000      1.000000      0.020000      0.000000      0.000000
# 25%        0.000000      1.000000      0.340000      0.333300      0.480000
# 50%        1.000000      1.000000      0.500000      0.484800      0.630000
# 75%        1.000000      2.000000      0.660000      0.621200      0.780000
# max        1.000000      4.000000      1.000000      1.000000      1.000000
#
#           windspeed           cnt
# count  17379.000000  17379.000000
# mean       0.190098    189.463088
# std        0.122340    181.387599
# min        0.000000      1.000000
# 25%        0.104500     40.000000
# 50%        0.194000    142.000000
# 75%        0.253700    281.000000
# max        0.850700    977.000000

# %% [markdown]
# ## Mostrar un mapa de calor que indique la correlación entre variables.

# %%
sns.set(rc = {'figure.figsize':(20, 10)})
sns.heatmap(bike.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Seleccionar las características a tener en cuenta en el estudio.

# %%
caracteristicas = ['weekday', 'temp', 'hum', 'cnt']
resultado = ['cnt']

# %% [markdown]
# ## Separar datos entre datos de entrada y etiquetas (resultados).

# %%
x_bike = bike[caracteristicas]
y_bike = bike[resultado]

# %% [markdown]
# ## Separar datos entre entrenamiento y prueba.

# %%
x_train = x_bike.loc['2011-01-01':'2012-06-30']
x_test = x_bike.loc['2012-07-01':]
y_train = y_bike.loc['2011-01-01':'2012-06-30']
y_test = y_bike.loc['2012-07-01':]

# %%
x_train.reset_index(drop = True, inplace = True)
x_test.reset_index(drop = True, inplace = True)
y_train.reset_index(drop = True, inplace = True)
y_test.reset_index(drop = True, inplace = True)

# %% [markdown]
# # Optimización de hiperparámetros.

# %% [markdown]
# ## Selección de hiperparametros.

# %%
param_dist = {
    'n_estimators': [32, 64, 128],
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
    'max_depth': [32, 16, 8, 4, 2],
    'max_features': ['auto', 'sqrt'],
    'bootstrap': [True, False]
}

# %% [markdown]
# ## Selección de modelo para la estimación.

# %%
classifier = RandomForestRegressor()

# %% [markdown]
# ## Validación cruzada.

# %% [markdown]
# ### GridSearchCV.

# %%
grid_search = GridSearchCV(estimator=classifier, param_grid=param_dist, cv=5)
grid_search.fit(x_train.values, y_train.values.ravel())
grid_search.best_estimator_

# %% [markdown]
# ### RandomizedSearchCV.

# %%
random_search = RandomizedSearchCV(estimator=classifier, param_distributions=param_dist, cv=5)
random_search.fit(x_train.values, y_train.values.ravel())
random_search.best_estimator_
# Out:
# RandomForestRegressor(criterion='absolute_error', max_depth=8, n_estimators=64)

# %% [markdown]
# # Entrenamiento y predicción.

# %% [markdown]
# ## Elegir, instanciar y entrenar el modelo.

# %%
model = grid_search.best_estimator_

# %%
model = random_search.best_estimator_

# %% [markdown]
# ## Realizar una predicción con los datos de prueba.

# %%
model.fit(x_train, y_train)
# Out:
# <ipython-input-29-139fa7af76d2>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train, y_train)
# RandomForestRegressor(criterion='absolute_error', max_depth=8, n_estimators=64)

# %%
y_predict = model.predict(x_test)

# %% [markdown]
# ## Mostrar la importancia de cada atributo en el árbol resultante.

# %%
print('Features Relevances')
pd.DataFrame({'Attributes': ('temp', 'hr', 'hum'), 'Decision Tree': model.feature_importances_ })
# Out:
# Features Relevances
#   Attributes  Decision Tree
# 0       temp       0.100427
# 1         hr       0.477869
# 2        hum       0.421703

# %% [markdown]
# ## Intenta guardar el modelo de predicción ya entrenado usando dump

# %%
dump(model, 'modelos_entrenado.AD_Bike')
# Out:
# ['modelos_entrenado.AD_Bike']

# %% [markdown]
# # Evaluación.

# %% [markdown]
# ## Mostrar el error cuadrático medio

# %%
mean_squared_error(y_test, y_predict)
# Out:
# 46757.322168200284

# %% [markdown]
# ## Mostrar el error absoluto medio

# %%
mean_absolute_error(y_test, y_predict)
# Out:
# 151.3193466493373

# %% [markdown]
# ##  Representar gráficamente los valores predichos con los valores reales.

# %%
plt.figure(figsize=(20,10))
xx = np.stack(i for i in range(200))
plt.plot(xx, y_test[:200], c='r', label='data')
plt.plot(xx, y_predict[:200], c='g', label='prediction')
plt.axis('tight')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3249: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
start = 3300
plt.figure(figsize=(20,10))
xx = np.stack(i for i in range(start, y_test.shape[0]))
plt.plot(xx, y_test[start:], c='r', label='data')
plt.plot(xx, y_predict[start:], c='g', label='prediction')
plt.axis('tight')
plt.legend()
plt.show()
